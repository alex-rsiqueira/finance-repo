# %% [markdown]
# <a href="https://colab.research.google.com/github/alex-rsiqueira/finance-repo/blob/main/nubankpy%20to%20Bigquery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nubank Integration

# %% [markdown]
# ## Setup

# %%
# !pip install -q google.appengine.api

# %%
# !pip install -q pynubank

# %%
# !pip install -q fsspec

# %%
from pynubank.utils.certificate_generator import CertificateGenerator
from google.cloud.bigquery._helpers import _record_field_to_json
from pynubank import Nubank, MockHttpClient, NuException
#from google.appengine.api import app_identity
from colorama import init, Fore, Style
from google.cloud import bigquery
from google.colab import auth
from getpass import getpass
from io import StringIO
import pandas as pd
import numpy as np
import datetime
import random
import string
import json
import os

# %%
carga_full = 1

# %% [markdown]
# ## Authentication

# %% [markdown]
# ### BigQuery

# %%
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# ### Nubank

# %% [markdown]
# #### Generate Certificate

# %%
log(f'Starting {Fore.MAGENTA}{Style.DIM}PyNubank{Style.NORMAL}{Fore.LIGHTBLUE_EX} context creation.')

device_id = generate_random_id()

log(f'Generated random id: {device_id}')

cpf = input(f'[>] Enter your CPF(Numbers only): ')
password = getpass('[>] Enter your password (Used on the app/website): ')

generator = CertificateGenerator(cpf, password, device_id)

log('Requesting e-mail code')
try:
    email = generator.request_code()
except NuException:
    log(f'{Fore.RED}Failed to request code. Check your credentials!', Fore.RED)
    return

log(f'Email sent to {Fore.LIGHTBLACK_EX}{email}{Fore.LIGHTBLUE_EX}')
code = input('[>] Type the code received by email: ')

cert1, cert2 = generator.exchange_certs(code)

save_cert(cert1, 'cert.p12')

print(f'{Fore.GREEN}Certificates generated successfully. (cert.pem)')
print(f'{Fore.YELLOW}Warning, keep these certificates safe (Do not share or version in git)')

# %% [markdown]
# #### Use certificate to connect

# %%
nu = Nubank()
refresh_token = nu.authenticate_with_cert('user', 'password', 'cert.p12')
#nu.authenticate_with_refresh_token(refresh_token, 'cert.p12')
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Client

# %% [markdown]
# #### Retrieve client information

# %%
client = nu.get_customer()

# %% [markdown]
# #### Delete unnecessary fields

# %%
del client['_links']
del client['devices']
del client['primary_device']
del client['external_ids']
del client['channels']
#del client['documents']

# Convert dict to json
client_json = json.dumps(client,ensure_ascii=False)

# %% [markdown]
# #### Create dataframe - df_client

# %%
df_client = pd.read_json(StringIO(client_json))
dtinsert = datetime.datetime.today().strftime('%Y-%m-%d %H:%M:%S')
df_client['dtinsert'] = dtinsert
df_client = df_client.drop('documents',1)
display(df_client)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   after removing the cwd from sys.path.
#   address_state          cpf                            email  \
# 0            SP  46983033892  alexsander_siqueira@outlook.com
#
#    address_postcode billing_address_line1 billing_address_state  \
# 0           4272300         Rua Vergueiro                    SP
#
#    address_number          address_ref_point billing_address_city  \
# 0            7170   estação Alto do Ipiranga            São Paulo
#
#            phone  ...  address_line1  profession  \
# 0  5511972854101  ...  Rua Vergueiro  consultant
#
#                 address_updated_at gender    last_atualizacao_cadastral_at  \
# 0 2021-03-29 13:42:24.976000+00:00   male 2020-07-20 14:01:10.703000+00:00
#
#   billing_address_number reported_income invitations  address_city  \
# 0                   7170            7500          10     São Paulo
#
#               dtinsert
# 0  2022-03-15 03:13:39
#
# [1 rows x 34 columns]

# %%
pd.set_option('display.max_rows', None)
display(df_client)
# Out:
# 0    {'id': '5984b754-a5dc-47dc-ab74-b67206cb8618',...
# Name: documents, dtype: object

# %% [markdown]
# #### Insert dataframe into BigQuery

# %%
## Insere registros do arquivo no BigQuery
bq_client = bigquery.Client(project='finances-314506')
dataset = bq_client.dataset(dataset_id='raw').table('tb_nubank_client')
table = bq_client.get_table(dataset)
insert_row = bq_client.insert_rows_from_dataframe(table=table, dataframe=df_client)
print(f"Tabela populada com sucesso: tb_nubank_client")
# Out:
# Tabela populada com sucesso: tb_nubank_client

# %% [markdown]
# #### Save client ID for future tables

# %%
client_id = df_client['id'][0]

# %% [markdown]
# ### Credit Card

# %% [markdown]
# #### Retrieve credit card transactions

# %%
transactions = nu.get_card_statements()

#Convert list to json
transactions_json = json.dumps(transactions)

# %% [markdown]
# #### Create dataframe - df_credit

# %%
df_credit = pd.read_json(StringIO(transactions_json))

# %% [markdown]
# #### Delete unnecessary fields and replace NaN values

# %%
del df_credit['_links']

#df_credit = df_credit.where(pd.notnull(df_credit), None)
df_credit = df_credit.astype(object).replace(np.nan, 'None')

display(df_credit)
# Out:
#                  description     category  amount                  time  \
# 0       Ebanx *Sonyplaystatn  transaction    5118  2022-03-14T21:40:05Z
# 1         Emporio Brasileiro  transaction    2440  2022-03-14T13:24:28Z
# 2     Rappi*Mr Shu Bar Resta  transaction    4985  2022-03-13T00:48:10Z
# 3           Uber *Uber *Trip  transaction    3495  2022-03-12T22:04:23Z
# 4           Uber *Uber *Trip  transaction    3603  2022-03-12T17:40:04Z
# ...                      ...          ...     ...                   ...
# 3633                  Viacao  transaction    3926  2017-08-19T21:16:02Z
# 3634  Thiago Alves Pereira D  transaction    1000  2017-08-18T16:14:20Z
# 3635            Trinity Cafe  transaction    2800  2017-08-18T16:07:25Z
# 3636          Doces do Porto  transaction    2230  2017-08-14T12:18:30Z
# 3637  Burger King Helio Pele  transaction    4080  2017-08-14T02:37:56Z
#
#                 source         title amount_without_iof  \
# 0     upfront_national        outros             5118.0
# 1     upfront_national  supermercado             2440.0
# 2     upfront_national   restaurante             4985.0
# 3     upfront_national    transporte             3495.0
# 4     upfront_national    transporte             3603.0
# ...                ...           ...                ...
# 3633              None    transporte               None
# 3634              None   restaurante               None
# 3635              None   restaurante               None
# 3636              None   restaurante               None
# 3637              None   restaurante               None
#
#                                    account  \
# 0     5984ced6-64d1-44ec-addb-932e839ba7cc
# 1     5984ced6-64d1-44ec-addb-932e839ba7cc
# 2     5984ced6-64d1-44ec-addb-932e839ba7cc
# 3     5984ced6-64d1-44ec-addb-932e839ba7cc
# 4     5984ced6-64d1-44ec-addb-932e839ba7cc
# ...                                    ...
# 3633                                  None
# 3634                                  None
# 3635                                  None
# 3636                                  None
# 3637                                  None
#
#                                                 details  \
# 0     {'status': 'unsettled', 'subcategory': 'card_n...
# 1     {'status': 'unsettled', 'subcategory': 'card_p...
# 2     {'status': 'settled', 'subcategory': 'card_not...
# 3     {'status': 'settled', 'subcategory': 'card_not...
# 4     {'status': 'settled', 'subcategory': 'card_not...
# ...                                                 ...
# 3633  {'lat': -23.64610250575807, 'lon': -46.6423459...
# 3634  {'lat': -23.53011105811048, 'lon': -46.6416518...
# 3635  {'lat': -23.52996586260791, 'lon': -46.6413158...
# 3636                    {'subcategory': 'card_present'}
# 3637  {'lat': -23.5979747912135, 'lon': -46.67380336...
#
#                                         id tokenized  \
# 0     622fb636-cfea-4363-a9bd-082149014fdc       0.0
# 1     622f420c-4954-4db5-acfc-ce2802eaa78a       1.0
# 2     622d3f4b-d0dd-425b-91df-56359767f2df       1.0
# 3     622d18e8-ada7-421e-8c36-b27a0edc8eee       0.0
# 4     622cdaf5-e4c1-4bbe-9ac5-cfbd6236147a       0.0
# ...                                    ...       ...
# 3633  5998aa92-e12c-4bf7-b5ac-eb1b9b4aa9c1      None
# 3634  5997125e-13bf-4e62-bcf5-c6f3de231329      None
# 3635  599710be-be68-4c92-beb6-adf7323bc899      None
# 3636  59919516-f8a8-4bcf-a083-840ebb1306d5      None
# 3637  59910d04-cf82-44b1-b9ca-4b12f7ecaecb      None
#
#                                                    href
# 0     nuapp://transaction/622fb636-cfea-4363-a9bd-08...
# 1     nuapp://transaction/622f420c-4954-4db5-acfc-ce...
# 2     nuapp://transaction/622d3f4b-d0dd-425b-91df-56...
# 3     nuapp://transaction/622d18e8-ada7-421e-8c36-b2...
# 4     nuapp://transaction/622cdaf5-e4c1-4bbe-9ac5-cf...
# ...                                                 ...
# 3633  nuapp://transaction/5998aa92-e12c-4bf7-b5ac-eb...
# 3634  nuapp://transaction/5997125e-13bf-4e62-bcf5-c6...
# 3635  nuapp://transaction/599710be-be68-4c92-beb6-ad...
# 3636  nuapp://transaction/59919516-f8a8-4bcf-a083-84...
# 3637  nuapp://transaction/59910d04-cf82-44b1-b9ca-4b...
#
# [3638 rows x 12 columns]

# %%
df_credit['details']
# Out:
# 0       {'status': 'unsettled', 'subcategory': 'card_n...
# 1       {'status': 'unsettled', 'subcategory': 'card_p...
# 2       {'status': 'settled', 'subcategory': 'card_not...
# 3       {'status': 'settled', 'subcategory': 'card_not...
# 4       {'status': 'settled', 'subcategory': 'card_not...
#                               ...
# 3633    {'lat': -23.64610250575807, 'lon': -46.6423459...
# 3634    {'lat': -23.53011105811048, 'lon': -46.6416518...
# 3635    {'lat': -23.52996586260791, 'lon': -46.6413158...
# 3636                      {'subcategory': 'card_present'}
# 3637    {'lat': -23.5979747912135, 'lon': -46.67380336...
# Name: details, Length: 3638, dtype: object

# %%
dtinsert = datetime.datetime.today().strftime('%Y-%m-%d %H:%M:%S')
df_credit['dtinsert'] = dtinsert
df_credit['id_client'] = str(client_id)

# %% [markdown]
# #### Insert dataframe into BigQuery

# %%
df_credit
# Out:
#                  description     category  amount                  time  \
# 0       Ebanx *Sonyplaystatn  transaction    5118  2022-03-14T21:40:05Z
# 1         Emporio Brasileiro  transaction    2440  2022-03-14T13:24:28Z
# 2     Rappi*Mr Shu Bar Resta  transaction    4985  2022-03-13T00:48:10Z
# 3           Uber *Uber *Trip  transaction    3495  2022-03-12T22:04:23Z
# 4           Uber *Uber *Trip  transaction    3603  2022-03-12T17:40:04Z
# ...                      ...          ...     ...                   ...
# 3633                  Viacao  transaction    3926  2017-08-19T21:16:02Z
# 3634  Thiago Alves Pereira D  transaction    1000  2017-08-18T16:14:20Z
# 3635            Trinity Cafe  transaction    2800  2017-08-18T16:07:25Z
# 3636          Doces do Porto  transaction    2230  2017-08-14T12:18:30Z
# 3637  Burger King Helio Pele  transaction    4080  2017-08-14T02:37:56Z
#
#                 source         title amount_without_iof  \
# 0     upfront_national        outros             5118.0
# 1     upfront_national  supermercado             2440.0
# 2     upfront_national   restaurante             4985.0
# 3     upfront_national    transporte             3495.0
# 4     upfront_national    transporte             3603.0
# ...                ...           ...                ...
# 3633              None    transporte               None
# 3634              None   restaurante               None
# 3635              None   restaurante               None
# 3636              None   restaurante               None
# 3637              None   restaurante               None
#
#                                    account  \
# 0     5984ced6-64d1-44ec-addb-932e839ba7cc
# 1     5984ced6-64d1-44ec-addb-932e839ba7cc
# 2     5984ced6-64d1-44ec-addb-932e839ba7cc
# 3     5984ced6-64d1-44ec-addb-932e839ba7cc
# 4     5984ced6-64d1-44ec-addb-932e839ba7cc
# ...                                    ...
# 3633                                  None
# 3634                                  None
# 3635                                  None
# 3636                                  None
# 3637                                  None
#
#                                                 details  \
# 0     {'status': 'unsettled', 'subcategory': 'card_n...
# 1     {'status': 'unsettled', 'subcategory': 'card_p...
# 2     {'status': 'settled', 'subcategory': 'card_not...
# 3     {'status': 'settled', 'subcategory': 'card_not...
# 4     {'status': 'settled', 'subcategory': 'card_not...
# ...                                                 ...
# 3633  {'lat': -23.64610250575807, 'lon': -46.6423459...
# 3634  {'lat': -23.53011105811048, 'lon': -46.6416518...
# 3635  {'lat': -23.52996586260791, 'lon': -46.6413158...
# 3636                    {'subcategory': 'card_present'}
# 3637  {'lat': -23.5979747912135, 'lon': -46.67380336...
#
#                                         id tokenized  \
# 0     622fb636-cfea-4363-a9bd-082149014fdc       0.0
# 1     622f420c-4954-4db5-acfc-ce2802eaa78a       1.0
# 2     622d3f4b-d0dd-425b-91df-56359767f2df       1.0
# 3     622d18e8-ada7-421e-8c36-b27a0edc8eee       0.0
# 4     622cdaf5-e4c1-4bbe-9ac5-cfbd6236147a       0.0
# ...                                    ...       ...
# 3633  5998aa92-e12c-4bf7-b5ac-eb1b9b4aa9c1      None
# 3634  5997125e-13bf-4e62-bcf5-c6f3de231329      None
# 3635  599710be-be68-4c92-beb6-adf7323bc899      None
# 3636  59919516-f8a8-4bcf-a083-840ebb1306d5      None
# 3637  59910d04-cf82-44b1-b9ca-4b12f7ecaecb      None
#
#                                                    href             dtinsert  \
# 0     nuapp://transaction/622fb636-cfea-4363-a9bd-08...  2022-03-15 03:17:53
# 1     nuapp://transaction/622f420c-4954-4db5-acfc-ce...  2022-03-15 03:17:53
# 2     nuapp://transaction/622d3f4b-d0dd-425b-91df-56...  2022-03-15 03:17:53
# 3     nuapp://transaction/622d18e8-ada7-421e-8c36-b2...  2022-03-15 03:17:53
# 4     nuapp://transaction/622cdaf5-e4c1-4bbe-9ac5-cf...  2022-03-15 03:17:53
# ...                                                 ...                  ...
# 3633  nuapp://transaction/5998aa92-e12c-4bf7-b5ac-eb...  2022-03-15 03:17:53
# 3634  nuapp://transaction/5997125e-13bf-4e62-bcf5-c6...  2022-03-15 03:17:53
# 3635  nuapp://transaction/599710be-be68-4c92-beb6-ad...  2022-03-15 03:17:53
# 3636  nuapp://transaction/59919516-f8a8-4bcf-a083-84...  2022-03-15 03:17:53
# 3637  nuapp://transaction/59910d04-cf82-44b1-b9ca-4b...  2022-03-15 03:17:53
#
#                                  id_client
# 0     5984b6bd-b065-460a-a9aa-bb4ec3af99de
# 1     5984b6bd-b065-460a-a9aa-bb4ec3af99de
# 2     5984b6bd-b065-460a-a9aa-bb4ec3af99de
# 3     5984b6bd-b065-460a-a9aa-bb4ec3af99de
# 4     5984b6bd-b065-460a-a9aa-bb4ec3af99de
# ...                                    ...
# 3633  5984b6bd-b065-460a-a9aa-bb4ec3af99de
# 3634  5984b6bd-b065-460a-a9aa-bb4ec3af99de
# 3635  5984b6bd-b065-460a-a9aa-bb4ec3af99de
# 3636  5984b6bd-b065-460a-a9aa-bb4ec3af99de
# 3637  5984b6bd-b065-460a-a9aa-bb4ec3af99de
#
# [3638 rows x 14 columns]

# %%
## Insere registros do arquivo no BigQuery
bq_client = bigquery.Client(project='finances-314506')
dataset = bq_client.dataset(dataset_id='raw').table('tb_nubank_credit')
table = bq_client.get_table(dataset)
insert_row = bq_client.insert_rows_from_dataframe(table=table, dataframe=df_credit)
print(f"Tabela populada com sucesso: tb_nubank_credit")
# Out:
# Tabela populada com sucesso: tb_nubank_credit

# %%
# Agrupa pelo campo "title" que é a categoria e soma os valores
df = pd.read_json(StringIO(transactions_json)).groupby(['title']).sum()

# Plota o gráfico baseado no campo amount
df['amount'].plot.pie(figsize=(6, 6), autopct='%.2f')

# %% [markdown]
# #### Retrieve information from specific bill

# %%
# Lista de dicionários contendo todas as faturas do seu cartão de crédito
bills = nu.get_bills()

# Retorna um dicionário contendo os detalhes de uma fatura retornada por get_bills()
#bill_details = nu.get_bill_details(bills[2])

# %%
bills[4]['summary']
# Out:
# {'close_date': '2022-05-09',
#  'due_date': '2022-05-16',
#  'effective_due_date': '2022-05-16',
#  'interest': 0,
#  'interest_rate': '0.14',
#  'minimum_payment': 0,
#  'open_date': '2022-04-09',
#  'paid': 0,
#  'past_balance': 0,
#  'total_balance': 84820,
#  'total_cumulative': 84820}

# %%
df_bills = pd.DataFrame(bills)
df_bills
# Out:
#       state                                            summary  \
# 0    future  {'due_date': '2022-09-16', 'close_date': '2022...
# 1    future  {'due_date': '2022-08-16', 'close_date': '2022...
# 2    future  {'due_date': '2022-07-16', 'close_date': '2022...
# 3    future  {'due_date': '2022-06-16', 'close_date': '2022...
# 4    future  {'due_date': '2022-05-16', 'close_date': '2022...
# ..      ...                                                ...
# 56  overdue  {'due_date': '2018-01-19', 'close_date': '2018...
# 57  overdue  {'due_date': '2017-12-19', 'close_date': '2017...
# 58  overdue  {'due_date': '2017-11-19', 'close_date': '2017...
# 59  overdue  {'due_date': '2017-10-19', 'close_date': '2017...
# 60  overdue  {'due_date': '2017-09-19', 'close_date': '2017...
#
#                                                _links  \
# 0                                                  {}
# 1                                                  {}
# 2                                                  {}
# 3                                                  {}
# 4                                                  {}
# ..                                                ...
# 56  {'self': {'href': 'https://prod-s0-facade.nuba...
# 57  {'self': {'href': 'https://prod-s0-facade.nuba...
# 58  {'self': {'href': 'https://prod-s0-facade.nuba...
# 59  {'self': {'href': 'https://prod-s0-facade.nuba...
# 60  {'self': {'href': 'https://prod-s0-facade.nuba...
#
#                                       id installment_button
# 0                                    NaN                NaN
# 1                                    NaN                NaN
# 2                                    NaN                NaN
# 3                                    NaN                NaN
# 4                                    NaN                NaN
# ..                                   ...                ...
# 56  5a582dc5-82a7-4ed0-8555-c17b0e53cb22                NaN
# 57  5a2f4f50-c2f2-479d-9da5-521dedde528b                NaN
# 58  5a07bf26-45a5-4e2d-9201-360f1c57f7bc                NaN
# 59  59dee360-f9a9-4772-96d5-a53e627f6be6                NaN
# 60  59b76180-abad-4cf8-ace7-f52ec75ccaf7                NaN
#
# [61 rows x 5 columns]

# %%
df_bills = pd.DataFrame(bills[6]['summary'], index=[0])

# %%
df_bills = df_bills[['open_date','due_date','total_balance','minimum_payment']]

# %%
df_bills
# Out:
#     open_date    due_date  total_balance  minimum_payment
# 0  2022-02-09  2022-03-16         887792           133169

# %%
int(datetime.datetime.today().strftime('%Y%m'))
# Out:
# 202203

# %%
df_bills.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 0 to 0
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   open_date        1 non-null      object
#  1   due_date         1 non-null      object
#  2   total_balance    1 non-null      int64
#  3   minimum_payment  1 non-null      int64
#  4   bill_id          1 non-null      object
#  5   bill_competence  1 non-null      object
#  6   state            1 non-null      object
#  7   id_client        1 non-null      object
#  8   dtinsert         1 non-null      object
# dtypes: int64(2), object(7)
# memory usage: 80.0+ bytes

# %%
for i in range(0,len(bills)):
    bill_state = bills[i]['state']
    if bill_state != 'future':
        #print(bill_state)
        if bill_state in ('closed','overdue'):
            bill_href = bills[i]['_links']['self']['href']
            bill_id = bill_href[::-1][:bill_href[::-1].find('/')][::-1]
        elif bill_state == 'open':
            bill_href = bills[i]['_links']['self']['href']
            bill_id = bill_href[::-1][bill_href[::-1].find('sllib/')+6:bill_href[::-1].find('/stnuocca')][::-1]
        else:
            bill_id = None

        bill_competence = bills[i]['summary']['open_date'][:-3]

        if (int(bill_competence.replace('-','')) > int(datetime.datetime.today().strftime('%Y%m'))-2 or carga_full == 1):
            df_bills = pd.DataFrame(bills[i]['summary'], index=[0])
            df_bills = df_bills[['open_date','due_date','total_balance','minimum_payment']]
            df_bills['bill_id'] = bill_id
            df_bills['bill_competence'] = bill_competence
            df_bills['state'] = bill_state
            df_bills['id_client'] = client_id
            dtinsert = datetime.datetime.today().strftime('%Y-%m-%d %H:%M:%S')
            df_bills['dtinsert'] = dtinsert
            
            ## Insere registros no BigQuery
            bq_client = bigquery.Client(project='finances-314506')
            dataset = bq_client.dataset(dataset_id='raw').table('tb_nubank_bills')
            table = bq_client.get_table(dataset)
            insert_row = bq_client.insert_rows_from_dataframe(table=table, dataframe=df_bills)
            print(f"Tabela populada com sucesso: tb_nubank_bills")


            bill_details = nu.get_bill_details(bills[i]) 

            # Cria dataframe com lançamentos de cada fatura
            df_bill_statements = pd.DataFrame(bill_details['bill']['line_items'])
            df_bill_statements['bill_id'] = bill_id
            df_bill_statements['bill_competence'] = bill_competence
            
            dtinsert = datetime.datetime.today().strftime('%Y-%m-%d %H:%M:%S')
            df_bill_statements['dtinsert'] = dtinsert
            df_bill_statements['id_client'] = client_id
            df_bill_statements = df_bill_statements.where(pd.notnull(df_bill_statements), None)
            df_bill_statements = df_bill_statements.astype(object).replace(np.nan, 'None')

            ## Insere registros no BigQuery
            bq_client = bigquery.Client(project='finances-314506')
            dataset = bq_client.dataset(dataset_id='raw').table('tb_nubank_bill_statements')
            table = bq_client.get_table(dataset)
            insert_row = bq_client.insert_rows_from_dataframe(table=table, dataframe=df_bill_statements)
            print(f"Tabela populada com sucesso: tb_nubank_bill_statements")
    
    if bill_state == 'future':
        bill_id = None
        bill_competence = bills[i]['summary']['open_date'][:-3]

        df_bills = pd.DataFrame(bills[i]['summary'], index=[0])
        df_bills = df_bills[['open_date','due_date','total_balance','minimum_payment']]
        df_bills['bill_id'] = bill_id
        df_bills['bill_competence'] = bill_competence
        df_bills['state'] = bill_state
        dtinsert = datetime.datetime.today().strftime('%Y-%m-%d %H:%M:%S')
        df_bills['dtinsert'] = dtinsert
        df_bills['id_client'] = client_id
        
        ## Insere registros no BigQuery
        bq_client = bigquery.Client(project='finances-314506')
        dataset = bq_client.dataset(dataset_id='raw').table('tb_nubank_bills')
        table = bq_client.get_table(dataset)
        insert_row = bq_client.insert_rows_from_dataframe(table=table, dataframe=df_bills)
        print(f"Tabela populada com sucesso: tb_nubank_bills")
# Out:
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements
# Tabela populada com sucesso: tb_nubank_bills
# Tabela populada com sucesso: tb_nubank_bill_statements

# %% [markdown]
# #### Check balance from specific bill

# %%
print(sum([t['amount'] for t in bill_details['bill']['line_items']])/100)
# Out:
# 558.53

# %% [markdown]
# ### Account

# %% [markdown]
# #### Check account balance

# %%
print(nu.get_account_balance())
# Out:
# 2.43

# %% [markdown]
# #### Retrieve account transactions

# %%
account_statement = nu.get_account_feed()

account_statement_json = json.dumps(account_statement)

# %% [markdown]
# #### Create dataframe - df_account_statement

# %%
df_account_statement = pd.read_json(StringIO(account_statement_json))
#display(df_account_statement)

# %% [markdown]
# #### Treat dataframe

# %%
df_account_statement
# Out:
#                                         id               __typename  \
# 0     622ffa28-cefa-4b92-b6a5-7421185a2f52  LendingTransferOutEvent
# 1     622cd4d2-65df-4863-abce-26563e6f0766         GenericFeedEvent
# 2     622b36f1-cd1f-40eb-8e66-4bdfd7c3b85b         GenericFeedEvent
# 3     622a0530-ad7c-4b2d-938c-4e2319a923c4         GenericFeedEvent
# 4     6229f936-77e4-40b4-854d-8899115ab4c9         GenericFeedEvent
# ...                                    ...                      ...
# 1122  5c584a60-58f6-43bd-8cb1-2ebea16e503f          TransferInEvent
# 1123  5c584ae6-bc9f-422c-8a70-046963168888         BillPaymentEvent
# 1124  5c0950c3-7fe4-49e4-9239-f9ccc0389fc5         BillPaymentEvent
# 1125  5c09504e-1b25-4c40-9fd3-d69a4811b54d          TransferInEvent
# 1126  6fee0374-5b1d-37da-9722-cf61896391a5             WelcomeEvent
#
#                        title  \
# 0           Parcela atrasada
# 1      Transferência enviada
# 2      Transferência enviada
# 3      Transferência enviada
# 4      Transferência enviada
# ...                      ...
# 1122  Transferência recebida
# 1123     Pagamento da fatura
# 1124     Pagamento da fatura
# 1125  Transferência recebida
# 1126  Bem vindo à sua conta!
#
#                                                  detail    postDate   amount  \
# 0                                            1ª parcela  2022-03-14     None
# 1                     Higor Teixeira da Silva\nR$ 70,00  2022-03-12     None
# 2                     TELEFONICA BRASIL S A \nR$ 106,90  2022-03-11     None
# 3                    Larissa Passine de Souza\nR$ 57,00  2022-03-10     None
# 4                       ROBERTA SANTOS OGATA\nR$ 600,00  2022-03-10     None
# ...                                                 ...         ...      ...
# 1122                                        R$ 2.362,00  2019-02-04   2362.0
# 1123                        Cartão Nubank - R$ 2.361,16  2019-02-04  2361.16
# 1124                        Cartão Nubank - R$ 1.284,46  2018-12-06  1284.46
# 1125                                        R$ 1.285,00  2018-12-06   1285.0
# 1126  Alexsander Rodrigues de Siqueira\nBanco 260 - ...  2018-12-06     None
#
#                                      originAccount destinationAccount
# 0                                             None               None
# 1                                             None               None
# 2                                             None               None
# 3                                             None               None
# 4                                             None               None
# ...                                            ...                ...
# 1122  {'name': 'Alexsander Rodrigues de Siqueira'}               None
# 1123                                          None               None
# 1124                                          None               None
# 1125  {'name': 'Alexsander Rodrigues de Siqueira'}               None
# 1126                                          None               None
#
# [1127 rows x 8 columns]

# %%
# replace NaN values
df_account_statement = df_account_statement.where(pd.notnull(df_account_statement), None)
df_account_statement['amount'] = df_account_statement['amount'].astype(object).replace(np.nan, 'None')

# %%
# rename column
df_account_statement = df_account_statement.rename(columns={'__typename': 'typename'})

# retrieve the name from the dict value
df_account_statement['originAccount'] = df_account_statement['originAccount'].apply(lambda x: x.get('name') if x != None else x)
df_account_statement['destinationAccount'] = df_account_statement['destinationAccount'].apply(lambda x: x.get('name') if x != None else x)

dtinsert = datetime.datetime.today().strftime('%Y-%m-%d %H:%M:%S')
df_account_statement['dtinsert'] = dtinsert
df_account_statement['id_client'] = client_id

display(df_account_statement)
# Out:
#                                         id                 typename  \
# 0     622ffa28-cefa-4b92-b6a5-7421185a2f52  LendingTransferOutEvent
# 1     622cd4d2-65df-4863-abce-26563e6f0766         GenericFeedEvent
# 2     622b36f1-cd1f-40eb-8e66-4bdfd7c3b85b         GenericFeedEvent
# 3     622a0530-ad7c-4b2d-938c-4e2319a923c4         GenericFeedEvent
# 4     6229f936-77e4-40b4-854d-8899115ab4c9         GenericFeedEvent
# ...                                    ...                      ...
# 1122  5c584a60-58f6-43bd-8cb1-2ebea16e503f          TransferInEvent
# 1123  5c584ae6-bc9f-422c-8a70-046963168888         BillPaymentEvent
# 1124  5c0950c3-7fe4-49e4-9239-f9ccc0389fc5         BillPaymentEvent
# 1125  5c09504e-1b25-4c40-9fd3-d69a4811b54d          TransferInEvent
# 1126  6fee0374-5b1d-37da-9722-cf61896391a5             WelcomeEvent
#
#                        title  \
# 0           Parcela atrasada
# 1      Transferência enviada
# 2      Transferência enviada
# 3      Transferência enviada
# 4      Transferência enviada
# ...                      ...
# 1122  Transferência recebida
# 1123     Pagamento da fatura
# 1124     Pagamento da fatura
# 1125  Transferência recebida
# 1126  Bem vindo à sua conta!
#
#                                                  detail    postDate   amount  \
# 0                                            1ª parcela  2022-03-14     None
# 1                     Higor Teixeira da Silva\nR$ 70,00  2022-03-12     None
# 2                     TELEFONICA BRASIL S A \nR$ 106,90  2022-03-11     None
# 3                    Larissa Passine de Souza\nR$ 57,00  2022-03-10     None
# 4                       ROBERTA SANTOS OGATA\nR$ 600,00  2022-03-10     None
# ...                                                 ...         ...      ...
# 1122                                        R$ 2.362,00  2019-02-04   2362.0
# 1123                        Cartão Nubank - R$ 2.361,16  2019-02-04  2361.16
# 1124                        Cartão Nubank - R$ 1.284,46  2018-12-06  1284.46
# 1125                                        R$ 1.285,00  2018-12-06   1285.0
# 1126  Alexsander Rodrigues de Siqueira\nBanco 260 - ...  2018-12-06     None
#
#                          originAccount destinationAccount  \
# 0                                 None               None
# 1                                 None               None
# 2                                 None               None
# 3                                 None               None
# 4                                 None               None
# ...                                ...                ...
# 1122  Alexsander Rodrigues de Siqueira               None
# 1123                              None               None
# 1124                              None               None
# 1125  Alexsander Rodrigues de Siqueira               None
# 1126                              None               None
#
#                  dtinsert                             id_client
# 0     2022-03-15 03:38:42  5984b6bd-b065-460a-a9aa-bb4ec3af99de
# 1     2022-03-15 03:38:42  5984b6bd-b065-460a-a9aa-bb4ec3af99de
# 2     2022-03-15 03:38:42  5984b6bd-b065-460a-a9aa-bb4ec3af99de
# 3     2022-03-15 03:38:42  5984b6bd-b065-460a-a9aa-bb4ec3af99de
# 4     2022-03-15 03:38:42  5984b6bd-b065-460a-a9aa-bb4ec3af99de
# ...                   ...                                   ...
# 1122  2022-03-15 03:38:42  5984b6bd-b065-460a-a9aa-bb4ec3af99de
# 1123  2022-03-15 03:38:42  5984b6bd-b065-460a-a9aa-bb4ec3af99de
# 1124  2022-03-15 03:38:42  5984b6bd-b065-460a-a9aa-bb4ec3af99de
# 1125  2022-03-15 03:38:42  5984b6bd-b065-460a-a9aa-bb4ec3af99de
# 1126  2022-03-15 03:38:42  5984b6bd-b065-460a-a9aa-bb4ec3af99de
#
# [1127 rows x 10 columns]

# %% [markdown]
# #### Insert dataframe into BigQuery

# %%
## Insere registros do arquivo no BigQuery
bq_client = bigquery.Client(project='finances-314506')
dataset = bq_client.dataset(dataset_id='raw').table('tb_nubank_account')
table = bq_client.get_table(dataset)
insert_row = bq_client.insert_rows_from_dataframe(table=table, dataframe=df_account_statement)
print(f"Tabela populada com sucesso: tb_nubank_account")
# Out:
# Tabela populada com sucesso: tb_nubank_account
